# %% [markdown]
# <a href="https://colab.research.google.com/github/Samitha10/LLM-Cookbook/blob/main/How_to_use_hugging_face_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 16.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %% [markdown]
# ### Import api keys

# %%
from google.colab import userdata
HF_key = userdata.get('HF_write')
print(HF_key)
# Out:
# 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

# %% [markdown]
# ### Hugging Face Endpoint
# This uses hugging face token api key to access model without downloading locally.It is using hugging face hub. Rates and limits are applied.

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key=userdata.get("HF")
print(sec_key)
# Out:
# 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

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke('what is gen AI in simple')
# Out:
# " terms?\n\nGen AI, or General Artificial Intelligence, refers to a type of artificial intelligence that has the ability to understand, learn, and apply knowledge across a wide range of tasks at a level equal to or beyond a human being. This means it can perform any intellectual task that a human can do, such as understanding language, recognizing objects, solving complex problems, and even exhibiting creativity and social intelligence. It's the kind of AI often depicted in science fiction as being capable of independent thought and action. However, it's important to note that we haven't yet developed Gen AI in the real world, and it's a topic of ongoing research and debate in the field of artificial intelligence."

# %%
from langchain import PromptTemplate, LLMChain
quection = 'who is sanath jayasooriya'
template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
chain = LLMChain(llm=llm, prompt=prompt)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(

# %%
chain.invoke(quection)
# Out:
# {'question': 'who is sanath jayasooriya',
#  'text': '\n\n1. Sanath Jayasooriya is a former Sri Lankan cricketer.\n2. He is a left-handed batsman and a right-arm off-break bowler.\n3. He played international cricket for Sri Lanka from 1989 to 2011.\n4. He is one of the most successful batsmen in One Day International (ODI) cricket history.\n5. He was the captain of the Sri Lankan cricket team from 1999 to 2004.\n6. He was the first cricketer to score a triple century in ODI cricket.\n7. He was also the first cricketer to score 13,000 runs in ODI cricket.\n8. He is a member of the ICC Cricket Hall of Fame.\n\nSo, Sanath Jayasooriya is a former Sri Lankan cricketer, one of the most successful batsmen in ODI cricket history, and a member of the ICC Cricket Hall of Fame.'}

# %% [markdown]
# ### HuggingFace Pipline
# Model is downloading directly in your local

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=128,
    temperature=0.7,
)

# %%
base = HuggingFacePipeline(pipeline=pipeline)
print(base)
# Out:
# HuggingFacePipeline
# Params: {'model_id': 'gpt2', 'model_kwargs': None, 'pipeline_kwargs': None}

# %%
base.invoke('Machine learning is ')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "Machine learning is \xa0a very important tool.\nIn this episode of Google's I/O conference, Google is using Machine Learning to teach its Google Search products. The machine learning is mostly used to tell Google what search queries people might like, for instance, so it can determine which of those search queries has the most positive results. The results are then used to decide which products to sell to consumers, and which to sell to Google.\nI should note that the machine learning is not a perfect solution: it tries to infer what people are looking for, but it can still only do so much. That is a shame because it"
